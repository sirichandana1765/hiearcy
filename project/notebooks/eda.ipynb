# %% [markdown]
# # EDA for Hierarchical Clustering
#
# This notebook explores the Mall Customers dataset and prepares it for hierarchical clustering.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/Mall_Customers.csv')
df.head()
